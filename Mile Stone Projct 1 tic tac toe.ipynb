# %%
# Then the empty board will appear.


def board():
    winner = ''
    from IPython.display import clear_output
    list_of_inputs = []
    range_of_input = [1,2,3,4,5,6,7,8,9]
    print('Welcome to Tic-Tac-Toe')
    # the gap between the 6 and 9 is four spaces
    location1 = '    '
    location2 = '    '
    location3 = '    '
    location4 = '    '
    location5 = '    '
    location6 = '    '
    location7 = '    '
    location8 = '    '
    location9 = '    '
    print (location7 + '|' + location8 + '|' + location9)
    print('_____________')
    print (location4 + '|' + location5 + '|' + location6)
    print('_____________')
    print (location1 + '|' + location2 + '|' + location3)
    
    #taking input from player zero first time first entry
    location = input('please player 0, enter your choice position')
    while location.isdigit() != True:
        print('you have entered a charecter that is not a number please enter carefully again.')
        location = input('please player 0, enter your choice position')
    while int(location) not in [x for x in range_of_input if x not in list_of_inputs]:
        print( 'you have entered a charecter which is not a number please enter again or is not allowed, allowed are integers 1 to 9 both included.')
        location = input('please player o, enter your choice postion.')
    list_of_inputs.append(int(location))




    #clearring the output
    clear_output()


    #then there should be a way to check that the number is in betwen 0 and 9.
    if int(location) == 1:
        location1 = '  o  '
    elif int(location) == 2:
        location2 = '  o  '
    elif int(location) == 3:
        location3 = '  o  '
    elif int(location) == 4:
        location4 = '  o  '
    elif int(location) == 5:
        location5 = '  o  '
    elif int(location) == 6:
        location6 = '  o  '
    elif int(location) == 7:
        location7 = '  o  '
    elif int(location) == 8:
        location8 = '  o  '
    elif int(location) == 9:
        location9 = '  o  '
    print (location7 + '|' + location8 + '|' + location9)
    print('_____________')
    print (location4 + '|' + location5 + '|' + location6)
    print('_____________')
    print (location1 + '|' + location2 + '|' + location3)

    
    
    
    #taking input from player x first time second entry
    locationx = input('please player x, enter your choice position')
    while locationx.isdigit() != True:
        print( 'you have entered a charecter which is not a number please enter again')
        locationx = input('please player x, enter your choice postion.')
    while int(locationx) not in [x for x in range_of_input if x not in list_of_inputs]:
        print('you had previously entered a wrong number please enter wisely now. (the input should be an integer from 1 to 9 both included)')
        locationx = input('please player x, enter your choice position.')
    list_of_inputs.append(int(location))




    #clearring the output
    clear_output()


    #then there should be a way to check that the number is in betwen 0 and 9.
    if int(locationx) == 1:
        location1 = '  x  '
    elif int(locationx) == 2:
        location2 = '  x  '
    elif int(locationx) == 3:
        location3 = '  x  '
    elif int(locationx) == 4:
        location4 = '  x  '
    elif int(locationx) == 5:
        location5 = '  x  '
    elif int(locationx) == 6:
        location6 = '  x  '
    elif int(locationx) == 7:
        location7 = '  x  '
    elif int(locationx) == 8:
        location8 = '  x  '
    elif int(locationx) == 9:
        location9 = '  x  '
    print (location7 + '|' + location8 + '|' + location9)
    print('_____________')
    print (location4 + '|' + location5 + '|' + location6)
    print('_____________')
    print (location1 + '|' + location2 + '|' + location3)


        
     #taking input from player zero second time third entry
    location = input('please player 0, enter your choice position')
    while location.isdigit() != True:
        print('you have entered a charecter that is not a number please enter carefully again.')
        location = input('please player 0, enter your choice position')
    while int(location) not in [x for x in range_of_input if x not in list_of_inputs]:
        print( 'you have entered a charecter which is not a number please enter again or is not allowed, allowed are integers 1 to 9 both included.')
        location = input('please player o, enter your choice postion.')
    list_of_inputs.append(int(location))





    #clearring the output
    clear_output()


    
    if int(location) == 1:
        location1 = '  o  '
    elif int(location) == 2:
        location2 = '  o  '
    elif int(location) == 3:
        location3 = '  o  '
    elif int(location) == 4:
        location4 = '  o  '
    elif int(location) == 5:
        location5 = '  o  '
    elif int(location) == 6:
        location6 = '  o  '
    elif int(location) == 7:
        location7 = '  o  '
    elif int(location) == 8:
        location8 = '  o  '
    elif int(location) == 9:
        location9 = '  o  '
    print (location7 + '|' + location8 + '|' + location9)
    print('_____________')
    print (location4 + '|' + location5 + '|' + location6)
    print('_____________')
    print (location1 + '|' + location2 + '|' + location3)

    
    
    #taking input from player x second time fourth entry
    locationx = input('please player x, enter your choice position')
    while locationx.isdigit() != True:
        print( 'you have entered a charecter which is not a number please enter again')
        locationx = input('please player x, enter your choice postion.')
    while int(locationx) not in[x for x in range_of_input if x not in list_of_inputs]:
        print('you had previously entered a wrong number please enter wisely now. (the input should be an integer from 1 to 9 both included)')
        locationx = input('please player x, enter your choice position.')
    list_of_inputs.append(int(location))





    #clearring the output
    clear_output()


    #then there should be a way to check that the number is in betwen 0 and 9.
    if int(locationx) == 1:
        location1 = '  x  '
    elif int(locationx) == 2:
        location2 = '  x  '
    elif int(locationx) == 3:
        location3 = '  x  '
    elif int(locationx) == 4:
        location4 = '  x  '
    elif int(locationx) == 5:
        location5 = '  x  '
    elif int(locationx) == 6:
        location6 = '  x  '
    elif int(locationx) == 7:
        location7 = '  x  '
    elif int(locationx) == 8:
        location8 = '  x  '
    elif int(locationx) == 9:
        location9 = '  x  '
    print (location7 + '|' + location8 + '|' + location9)
    print('_____________')
    print (location4 + '|' + location5 + '|' + location6)
    print('_____________')
    print (location1 + '|' + location2 + '|' + location3)
    
    #such that game may only stop when all the cells are filled or someone has won already
    while len(range_of_input)!= 0:
        location = input('please player 0, enter your choice position')
        while location.isdigit() != True:
            print('you have entered a charecter that is not a number please enter carefully again.')
            location = input('please player 0, enter your choice position')
        while int(location) not in [x for x in range_of_input if x not in list_of_inputs]:
            print( 'you have entered a charecter which is not a number please enter again or is not allowed, allowed are integers 1 to 9 both included.')
            location = input('please player o, enter your choice postion.')
        list_of_inputs.append(int(location))

        #clearing the output
        clear_output()

        #then there should be a way to check that the number is in betwen 0 and 9.
        if int(location) == 1:
            location1 = '  o  '
        elif int(location) == 2:
            location2 = '  o  '
        elif int(location) == 3:
            location3 = '  o  '
        elif int(location) == 4:
            location4 = '  o  '
        elif int(location) == 5:
            location5 = '  o  '
        elif int(location) == 6:
            location6 = '  o  '
        elif int(location) == 7:
            location7 = '  o  '
        elif int(location) == 8:
            location8 = '  o  '
        elif int(location) == 9:
            location9 = '  o  '
        print (location7 + '|' + location8 + '|' + location9)
        print('_____________')
        print (location4 + '|' + location5 + '|' + location6)
        print('_____________')
        print (location1 + '|' + location2 + '|' + location3)


        #now the logic to check will come here in function.
        # game logic
       #game logic 1
        if location2 == location3 == location1!= '    ':
            winner = location1[::]
            print(f'the player with {location2} is the winner')
            return winner 
        if location6 == location9 == location3!= '    ':
            winner = location6[::]
            print(f'the player with {location6} is the winner')
            return winner
        if location8 == location9 == location7!= '    ':
            print(f'the player with {location8} is the winner')
            winner = location8[::]
            return winner
        if location4 == location1 == location7!= '    ':
            print(f'the player with {location4} is the winner')
            winner = location4[::]
            return winner
        elif location5 == location1 == location9!= '    ' or location2 == location5 == location8!= '    ' or location3 == location5 == location7!= '    ':
            winner = location5[::]
            print(f'the player with {location5} is the winner')
            return winner
        elif location4 ==location5==location6!= '    ' or location2== location5 == location8!= '    ':
            winner = location5[::]
            return winner







        #taking input from player x third time sixth entry 
        locationx = input('please player x, enter your choice position')
        while locationx.isdigit() != True:
            print( 'you have entered a charecter which is not a number please enter again')
            locationx = input('please player x, enter your choice postion.')
        while int(locationx) not in [x for x in range_of_input if x not in list_of_inputs]:
            print('you had previously entered a wrong number please enter wisely now. (the input should be an integer from 1 to 9 both included)')
            locationx = input('please player x, enter your choice position.')
        list_of_inputs.append(int(location))





        #clearring the output
        clear_output()


        #then there should be a way to check that the number is in betwen 0 and 9.
        if int(locationx) == 1:
            location1 = '  x  '
        elif int(locationx) == 2:
            location2 = '  x  '
        elif int(locationx) == 3:
            location3 = '  x  '
        elif int(locationx) == 4:
            location4 = '  x  '
        elif int(locationx) == 5:
            location5 = '  x  '
        elif int(locationx) == 6:
            location6 = '  x  '
        elif int(locationx) == 7:
            location7 = '  x  '
        elif int(locationx) == 8:
            location8 = '  x  '
        elif int(locationx) == 9:
            location9 = '  x  '
        print (location7 + '|' + location8 + '|' + location9)
        print('_____________')
        print (location4 + '|' + location5 + '|' + location6)
        print('_____________')
        print (location1 + '|' + location2 + '|' + location3)


           #game logic 2
        if location2 == location3 == location1!= '    ':
            winner = location1[::]
            print(f'the player with {location2} is the winner')
            return winner 
        if location6 == location9 == location3!= '    ':
            winner = location6[::]
            print(f'the player with {location6} is the winner')
            return winner
        if location8 == location9 == location7!= '    ':
            print(f'the player with {location8} is the winner')
            winner = location8[::]
            return winner
        if location4 == location1 == location7!= '    ':
            print(f'the player with {location4} is the winner')
            winner = location4[::]
            return winner
        elif location5 == location1 == location9!= '    ' or location2!= '    ' == location5 == location8 or location3!= '    ' == location5 == location7:
            winner = location5[::]
            print(f'the player with {location5} is the winner')
            return winner
        elif location4 ==location5==location6!= '    ' or location2== location5 == location8!= '    ':
            winner = location5[::]
            return winner
    print('you both are equally intelligent, this game ties ')
    #end

# %%
board()
# Out:
# Welcome to Tic-Tac-Toe
#     |    |
# _____________
#     |    |
# _____________
#     |    |
